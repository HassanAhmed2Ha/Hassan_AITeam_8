# %% [markdown]
# When I opened the task file and read it completely I went and searched on YouTube for trapezoid rule for integration but I felt like I didnt understand anything just memorizing a rule I wanted to know the logic behind this rule why we use it and why it was created in the first place After a long search I realized that the first step is understanding the meaning of coordinates and area and I watched these two playlists
#
# 1 https://youtube.com/playlist?list=PLiT3pCvK_cfWOljGPMnFE5QW4nkLQ4Kfb&si=T-mC3NipLVSWghvV To understand coordinates
#
# 2 https://youtube.com/playlist?list=PLiT3pCvK_cfVb-0PH8Em55F1TRCHDdwZe&si=v3saSOqyId2za9HL To understand area
#
# After gaining a deep understanding of them
#
# I went to search for the trapezoid rule for integration and found videos explaining the definite integral law and its relationship to the trapezoid rule I found that despite its high accuracy it wasnt suitable for solving complex equations so I searched for an easier though less accurate method and found the solution using numerical integration I watched this video https://youtu.be/My9dm_QRVuo to understand the rule and the logic behind its use and then I tried solving several problems At first I made a lot of mistakes but with practice reviewing videos and searching on several websites the mistakes decreased and I came to understand the trapezoid rule for integration well

# %% [markdown]
# Examples of exercises:

# %% [markdown]
# ![unnamed.jpg](attachment:a0028c0f-d98d-4f94-b79a-2e214d90f15b.jpg)

# %% [markdown]
# step 1 calculate the step size h
# $$h = \frac{b - a}{n} = \frac{3 - 1}{2} = 1$$
#
# step 2 find the heights
# $$f(1) = 1^2 + 2 = 3$$
# $$f(2) = 2^2 + 2 = 6$$
# $$f(3) = 3^2 + 2 = 11$$
#
# step 3 calculate the final area
# $$A \approx \frac{h}{2} [f(1) + 2f(2) + f(3)]$$
# $$A \approx \frac{1}{2} [3 + 2(6) + 11]$$
# $$A \approx \frac{1}{2} [26] = 13$$

# %% [markdown]
# ### note to the reviewer i used google gemini to generate the practice problem but I solved it bymy self
